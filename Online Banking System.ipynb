# %% [markdown]
# # Banking System

# %%
class Customer :
    #defining the constructor function which inputs all the attributes such as name, username, password etc.
    def __init__(self):
        #initialising the class variables by taking input from the user itself
        self.accountnumber=input("Enter Account Number :")
        self.name=input("Enter Name of the customer : ")
        self.username=input("Enter Username : ")
        self.password=input("Enter Password : ")
        self.age=int(input("Enter age of the customer : "))
        self.gender=input("Gender :")
        self.contact=input("Enter Contact Number of customer : ")
        self.email=input("Enter E mail of customer")
        self.address=input("Enter address of the customer : ")
        #initialising account balance and fixed deposit class varialbes
        self.balance=0
        self.fixedDeposit=[]
    #defining the account() function. Account function is the only public function present in the Customer class. 
    #It will be used to access all the private functions
    def account(self,username,password):
        if password==self.password:
            print("  You have entered into account section of ",self.name,"'s account  ")
            print("********************************************************************")
            print("\t 1. Profile ")
            print("\t 2. Account Balance ")
            print("\t 3. Deposits ")
            print("\t 4. Funds Transfer ")
            print("\t 5. Change username/password ")
            choice=int(input("Enter Your Choice : "))
            #Conditional if else statements
            if choice==1:
                self.__profile()
            elif choice==2:
                self.__balance()
            elif choice==3:
                self.__deposits()
            elif choice==4:
                self.__fundTransfer()
            elif choice==5:
                self.__editProfile()
            else :
                print("Invalid Choice Loging Out")
    #defining __profile() as a private function of Customer class. It displays the information regarding 
    #the Customer such as Name,Age,Gender,etc.
    def __profile(self):
        print("Name              : ",self.name)
        print("Age               : ",self.age," Years")
        print("Gender            : ",self.gender)
        print("Contact           : ",self.contact)
        print("Email             : ",self.email)
        print("Permanent address : ",self.address)
        self.account(self.username,self.password)
    #defining __balance() as a private function used to view and add funds in the user account.
    def __balance(self):
        print("\t 1. Show Balance ")
        print("\t 2. Add Funds ")
        choice=int(input("Enter Your Choice : "))
        #conditional if-else statements are used to run command based on input of the user.
        if choice==1:
            print("Balance : ",self.balance)
            self.account(self.username,self.password)
        elif choice==2:
            self.__addFunds()
        else :
            print("Invalid Choice !!!")
            self.account(self.username,self.password)
    #defining __addFunds() as a private function which is used to add funds in the user account. 
    def __addFunds(self):
        add=int(input("Amount to add : "))
        self.balance+=add
        self.account(self.username,self.password)
    #defining __deposits() as private function which is used to create and show deposits made by the user 
    def __deposits(self):
        print("\t 1. Create Fixed Deposit")
        print("\t 2. View Fixed Depoists")
        choice=int(input("Enter Your Choice : "))
        if choice==1:
            if(self.balance>0):
                print("Account Balance : ",self.balance )
                amount=int(input("Amount for FD : "))
                if(amount<self.balance):
                    self.balance-=amount
                    self.fixedDeposit.append(amount)
                else:
                    print("Insufficient Funds")
                    self.account(self.username,self.password)
            else:
                print("Insufficient Funds")
                self.account(self.username,self.password)
        elif choice==2:
            print("Available Fixed Deposits are")
            for i in self.fixedDeposit:
                print("\t FD : ",i)
                self.account(self.username,self.password)
        else:
            print("Invalid Choice !!!")
            self.account(self.username,self.password)
    # defining __fundTransfer as a private function which is used to transfer funds from one user account to the other.
    def __fundTransfer(self):
        print("Account balance : ",self.balance)
        amount=int(input("Enter Amount to transfer : "))
        #verifying the funds present in the user account.
        if(amount<self.balance):
            accountno=input("Enter Account Number for Transfer")
            #looping statement to verify whether the account number is present in the list 
            for i in list:
                if i.accountnumber==accountno:
                    #funds deducted from user account
                    self.balance-=amount
                    #funds are transfered to the mentioned account
                    i.balance+=amount
                    print("Successfully Transfered !!!")
                    self.account(self.username,self.password)
                    #break statement to breakout of the loop
                    break
        else:
            print("Insufficient Funds!!! Add funds")
            self.__addFunds()
    #defining the __editProfile() as a private function which helps the user to alter the username and password of user account.
    def __editProfile(self):
        print("\t 1. Change Username ")
        print("\t 2. Change Password ")
        choice=int(input("Enter Your Choice : "))
        if choice==1:
            nuser=input("Enter new  Username :")
            self.username=nuser
            print("Username changed successfully ")
            self.account(self.username,self.password)
        if choice==2:
            npword=input("Enter new password : ")
            self.password=npword
            print("Password changed successfully ")
            self.account(self.username,self.password)

# %%
#Defining the login() function which helps the user to securely login into the user account.
#It asks for username and password for authentication of the user and calls account() function if validation is sucessfull
def login():
    uname=input("Username : ")
    pword=input("Password : ")
    for i in list:
        if uname==i.username:
            if pword==i.password:
                i.account(uname,pword)
                break
            else:
                print("Invalid Password")
                break
        else:
            print("Invalid Username")

# %%
list=[] # Empty list create to add objects of the class Customer
list.append(Customer())   #Adding Object of Coustmer class into list
# Out:
# Enter Account Number :00001
# Enter Name of the customer : Yash Jain
# Enter Username : yash2708
# Enter Password : 12345
# Enter age of the customer : 20
# Gender :M
# Enter Contact Number of customer : 1234567890
# Enter E mail of customerabc@gmail.com
# Enter address of the customer : abc

# %%
list.append(Customer())
# Out:
# Enter Account Number :00002
# Enter Name of the customer : N Kushal
# Enter Username : nk2000
# Enter Password : 54321
# Enter age of the customer : 20
# Gender :M
# Enter Contact Number of customer : 0987654321
# Enter E mail of customerdef@gmail.com
# Enter address of the customer : def

# %%
login()
# Out:
# Username : yash2708
# Password : 1234
# Invalid Password

# %%
login()
# Out:
# Username : yash2708
# Password : 12345
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 1
# Name              :  Yash Jain
# Age               :  20  Years
# Gender            :  M
# Contact           :  1234567890
# Email             :  abc@gmail.com
# Permanent address :  abc
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 2
# 	 1. Show Balance
# 	 2. Add Funds
# Enter Your Choice : 1
# Balance :  0
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# ...

# %%
login()
# Out:
# Username : yash2708
# Password : 12345
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 3
# 	 1. Create Fixed Deposit
# 	 2. View Fixed Depoists
# Enter Your Choice : 2
# Available Fixed Deposits are
# 	 FD :  2000
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 4
# Account balance :  8000
# Enter Amount to transfer : 3000
# Enter Account Number for Transfer00002
# Successfully Transfered !!!
#   You have entered into account section of  Yash Jain 's account
# ********************************************************************
# 	 1. Profile
# ...

# %%
login()
# Out:
# Username : nk2000
# Password : 54321
# Invalid Username
#   You have entered into account section of  N Kushal 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 2
# 	 1. Show Balance
# 	 2. Add Funds
# Enter Your Choice : 1
# Balance :  3000
#   You have entered into account section of  N Kushal 's account
# ********************************************************************
# 	 1. Profile
# 	 2. Account Balance
# 	 3. Deposits
# 	 4. Funds Transfer
# 	 5. Change username/password
# Enter Your Choice : 0
# Invalid Choice Loging Out
